# %% [markdown]
# # 7. Data Visualization I
# 1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information
# about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to
# see if we can find any patterns in the data.
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger
# is distributed by plotting a histogram.
# .

# %% [markdown]
# # 1. Document Preprocessing

# %%
text = """Text analytics is the process of deriving meaning from text. 
It uses NLP, machine learning, and statistics to convert text into useful data."""

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Titanic dataset from an online CSV (since we aren't using seaborn)
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
titanic = pd.read_csv(url)

# Plot histogram using matplotlib
plt.figure(figsize=(10, 6))
plt.hist(titanic['Fare'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Titanic Ticket Fare')
plt.xlabel('Fare')
plt.ylabel('Number of Passengers')
plt.grid(True)
plt.show()
